# %% [markdown]
# <a href="https://colab.research.google.com/github/Ariel-Pineapple/repositorio-de-ejemplo/blob/main/Estructuras_de_Datos_y_Control_de_flujo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **UNIVERSIDAD TECMILENIO**
#
#
# FUNDAMENTOS Y APLICACIONES DE INTELIGENCIA ARTIFICIAL
#
#
# SESIÓN 5:  TEMA 10 - INTRODUCCIÓN AL LENGUAJE DE PROGRAMACIÓN EN PYTHON

# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %% [markdown]
# ¿cómo recuerdo datos en python?
#
# Variables
#
# ¿Cuál es tu nombre?
# - Luis
#
# "Te llamaré: Luis" -  Asignar
# Símbolo de asignación en programación es =
#
# nombre = Luis

# %%
nombre = "Luis"

# %%
nombre
# Out:
# 'Luis'

# %% [markdown]
# ¿Qué edad tienes (años)?
# - 40

# %%
nombre = "Luis"
edad = 40

# %%
edad
# Out:
# 40

# %% [markdown]
# Tipos de Datos EN PROGRAMACIÓN
#
# Texto - ABCEDPS, palabras, caracteres, etc. -
# Números - para operaciones matemáticas
#
# Números enteros
# Números flotantes

# %%
print("5+5")
# Out:
# 5+5

# %%
print(5+5)
# Out:
# 10

# %%
print("5"+"5")
# Out:
# 55
